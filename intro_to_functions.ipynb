# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
name = 'naomi sundani'

# %%
def count_evens(arr):
    """This function takes a list of numbers
        and counts the number of even elements
        and returns the count
        
    @param arr: a list of positive numbers
    @return: an int of the number of positive elements in arr
    """
    for item in arr:
        if item < 0:
            return 'ERROR: ALL ITEMS MUST BE >= O'
        
    count = 0
    for item in arr:
        if item % 2 == 0:
            count+=1
            
    return count

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('exercise')
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
clean_df = df.copy()
clean_df.head(3)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest

# %%
clean_df['time_secs'] = df.time.apply(lambda x: x.split()[0])

# %%
clean_df.time_secs = clean_df.time_secs.astype('int')

# %%
clean_df.time_secs = clean_df.time_secs * 60

# %%
clean_df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind  time_secs
# 0           0   1  low fat     85   1 min  rest         60
# 1           1   1  low fat     85  15 min  rest        900
# 2           2   1  low fat     88  30 min  rest       1800
# 3           3   2  low fat     90   1 min  rest         60
# 4           4   2  low fat     92  15 min  rest        900

# %%
clean_df['time_per_pulse'] = clean_df.time_secs / clean_df.pulse

# %%
clean_df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind  time_secs  time_per_pulse
# 0           0   1  low fat     85   1 min  rest         60        0.705882
# 1           1   1  low fat     85  15 min  rest        900       10.588235
# 2           2   1  low fat     88  30 min  rest       1800       20.454545
# 3           3   2  low fat     90   1 min  rest         60        0.666667
# 4           4   2  low fat     92  15 min  rest        900        9.782609

# %%
plt.figure(figsize=(12, 8))
clean_df.hist(figsize=(12,8))
plt.show()

# %%
def convert(x):
    ty_res = time.gmtime(x)
    res = time.strftime("%H:%M:%S",ty_res)
    return res

# %%
clean_df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind  time_secs  time_per_pulse
# 0           0   1  low fat     85   1 min  rest         60        0.705882
# 1           1   1  low fat     85  15 min  rest        900       10.588235
# 2           2   1  low fat     88  30 min  rest       1800       20.454545
# 3           3   2  low fat     90   1 min  rest         60        0.666667
# 4           4   2  low fat     92  15 min  rest        900        9.782609

# %%
clean_df['time_str2'] = clean_df.time_secs.apply(lambda x: convert(x))

# %%
clean_df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind  time_secs  time_per_pulse  \
# 0           0   1  low fat     85   1 min  rest         60        0.705882
# 1           1   1  low fat     85  15 min  rest        900       10.588235
# 2           2   1  low fat     88  30 min  rest       1800       20.454545
# 3           3   2  low fat     90   1 min  rest         60        0.666667
# 4           4   2  low fat     92  15 min  rest        900        9.782609
#
#    time_str time_str2
# 0  00:01:00  00:01:00
# 1  00:15:00  00:15:00
# 2  00:30:00  00:30:00
# 3  00:01:00  00:01:00
# 4  00:15:00  00:15:00

# %%
clean_df.drop(columns=['time_str'], inplace=True)

# %%
clean_df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind  time_secs  time_per_pulse
# 0           0   1  low fat     85   1 min  rest         60        0.705882
# 1           1   1  low fat     85  15 min  rest        900       10.588235
# 2           2   1  low fat     88  30 min  rest       1800       20.454545
# 3           3   2  low fat     90   1 min  rest         60        0.666667
# 4           4   2  low fat     92  15 min  rest        900        9.782609

# %%
for index, row in clean_df.iterrows():
