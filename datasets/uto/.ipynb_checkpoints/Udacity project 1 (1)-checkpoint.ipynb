# %% [markdown]
# ##                                    NO-SHOW APPOINTMENTS ANALYSIS

# %% [markdown]
# ### Introduction
#
# In this project, I'll be analysing a dataset of patients that miss their self-booked appointments. I'll be looking for trends among patients who missed their appointment and how they differed from those who didn't miss their appointments.
#
# The dataset has columns to identify the patients and the appointment day(**Patientid** and **Appointmentid** respectively), **Gender**, **ScheduledDay**(tells us on what day the patient set up their appointment), **AppointmentDay**(the day the patients shows up for consultation/treatment), **Age**, **Neighborhood**(which is the location of the hospital), **Scholarship**(which shows whether or not the patient is enrolled in Brasilian welfare program Bolsa Família), if the patients have terminal illnesses(**Hipertension** and **Diabetes**),**Handcap**, **alcoholism**, **SMS_received**, and **No-show**.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### Data Wrangling

# %%
no_df = pd.read_csv('noshowappointments-kagglev2-may-2016.csv')
no_df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %%
no_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
sum(no_df.duplicated())
# Out:
# 0

# %%
no_df.Gender.value_counts()
# Out:
# F    71840
# M    38687
# Name: Gender, dtype: int64

# %%
no_df.nunique()
# Out:
# PatientId          62299
# AppointmentID     110527
# Gender                 2
# ScheduledDay      103549
# AppointmentDay        27
# Age                  104
# Neighbourhood         81
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# Handcap                5
# SMS_received           2
# No-show                2
# dtype: int64

# %%
no_df['Age'].value_counts()
# Out:
#  0      3539
#  1      2273
#  52     1746
#  49     1652
#  53     1651
#         ...
#  115       5
#  100       4
#  102       2
#  99        1
# -1         1
# Name: Age, Length: 104, dtype: int64

# %%
no_df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       4.000000
#
#         SMS_received
# count  110527.000000
# mean        0.321026
# std         0.466873
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# The dataset contains 110527 non-null records with 14 variables.
# Females are more than males and the mean age is 37 years.
# There are 62299 unique values in PatientId column but I won't touch the duplicates because a patient can have multiple visits to the hospital.

# %% [markdown]
# ### Data Cleaning

# %%
# correcting wrongly spelt headers
no_df.rename(columns = {'Hipertension' : 'Hypertensive', 'Handcap' : 'Handicap', 'Diabetes' : 'Diabetic','Alcoholism' : 'Alcoholic' }, inplace = True)

# %%
# making column headers consistent
no_df.rename(columns = lambda x: x.lower().replace("-", "_").strip(),inplace = True)
no_df.head(2)
# Out:
#       patientid  appointmentid gender          scheduledday  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
#
#          appointmentday  age    neighbourhood  scholarship  hypertensive  \
# 0  2016-04-29T00:00:00Z   62  JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56  JARDIM DA PENHA            0             0
#
#    diabetic  alcoholic  handicap  sms_received no_show
# 0         0          0         0             0      No
# 1         0          0         0             0      No

# %%
#convert scheduledday and appointmentday from strings to datetime datatype
no_df.loc[:,['scheduledday', 'appointmentday']] = no_df.loc[:,['scheduledday', 'appointmentday']].apply(pd.to_datetime)
no_df.head(2)
# Out:
#       patientid  appointmentid gender              scheduledday  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
#
#              appointmentday  age    neighbourhood  scholarship  hypertensive  \
# 0 2016-04-29 00:00:00+00:00   62  JARDIM DA PENHA            0             1
# 1 2016-04-29 00:00:00+00:00   56  JARDIM DA PENHA            0             0
#
#    diabetic  alcoholic  handicap  sms_received no_show
# 0         0          0         0             0      No
# 1         0          0         0             0      No

# %%
# Change the age of -1 to 1. I'm guessing that to be a typo error
no_df['age'].replace(-1, 1, inplace = True)

print(no_df['age'].value_counts()) #confirming the change has been made
# Out:
# 0      3539
# 1      2274
# 52     1746
# 49     1652
# 53     1651
#        ...
# 98        6
# 115       5
# 100       4
# 102       2
# 99        1
# Name: age, Length: 103, dtype: int64

# %% [markdown]
# ## Research Questions
#
#  1. What is the percentage of patients that did not show up for their appointments?
#
#  2. Which neighbourhood has the highest number of missed appointment?
#
#  3. What is the proportion of patients with scholarship that missed their appointment?
#
#  4. Is there any difference in the age distribution of patients that missed their appointments to those who didn't?

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# #### 1. What is the percentage of patients that did not show up for their appointments?

# %%
no_df['no_show'].value_counts().plot(kind = 'pie', title = "Percentage of patients that showed(No)/didn't show up(Yes) for their appointments", autopct='%1.1f%%');

# %%
no_df.groupby('no_show').gender.value_counts().plot(kind = 'pie',title = "Percentage of patients that showed(No)/didn't show up(Yes) for their appointments by gender", autopct='%1.1f%%');

# %% [markdown]
# It seems a great percentage of patients keep to their appointments and the female class do better than the male class. But even with the 20.2% of patients that miss their appointments, females still have a higher percentage. This could be as a result of the female class being more than the male in the dataset.  let's explore more on the percentage of patients that didn't show up for their appointments to see what they have in common.

# %%
# creating a dataFrame of patients that missed their appointments before going into the analysis
missed_df = no_df.query('no_show == "Yes"')
missed_df.head()
# Out:
#        patientid  appointmentid gender              scheduledday  \
# 6   7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7   3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 11  7.542951e+12        5620163      M 2016-04-26 08:44:12+00:00
# 17  1.479497e+13        5633460      F 2016-04-28 09:28:57+00:00
# 20  6.222575e+14        5626083      F 2016-04-27 07:51:14+00:00
#
#               appointmentday  age   neighbourhood  scholarship  hypertensive  \
# 6  2016-04-29 00:00:00+00:00   23      GOIABEIRAS            0             0
# 7  2016-04-29 00:00:00+00:00   39      GOIABEIRAS            0             0
# 11 2016-04-29 00:00:00+00:00   29  NOVA PALESTINA            0             0
# 17 2016-04-29 00:00:00+00:00   40       CONQUISTA            1             0
# 20 2016-04-29 00:00:00+00:00   30  NOVA PALESTINA            0             0
#
#     diabetic  alcoholic  handicap  sms_received no_show
# 6          0          0         0             0     Yes
# 7          0          0         0             0     Yes
# 11         0          0         0             1     Yes
# 17         0          0         0             0     Yes
# 20         0          0         0             0     Yes

# %%
missed_df.shape
# Out:
# (22319, 14)

# %%
meet_df = no_df.query('no_show == "No"')
meet_df.head()
# Out:
#       patientid  appointmentid gender              scheduledday  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              appointmentday  age      neighbourhood  scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    hypertensive  diabetic  alcoholic  handicap  sms_received no_show
# 0             1         0          0         0             0      No
# 1             0         0          0         0             0      No
# 2             0         0          0         0             0      No
# 3             0         0          0         0             0      No
# 4             1         1          0         0             0      No

# %% [markdown]
# #### 2. Which neighbourhood has the highest number of missed appointment?

# %%
missed_df['neighbourhood'].value_counts().plot(kind = 'bar', figsize = (20,10))
plt.xlabel('Neighbourhood')
plt.ylabel('Number of missed appointments')
plt.title('Missed appointments by neighbourhood');

# %% [markdown]
# #### 3. What is the proportion of patients with scholarship that missed their appointment?

# %%
missed_scholarship = missed_df['scholarship'].value_counts()
missed_scholarship
# Out:
# 0    19741
# 1     2578
# Name: scholarship, dtype: int64

# %%
meet_scholarship = meet_df['scholarship'].value_counts()

# %%
total_scholarship = no_df['scholarship'].value_counts()

# %% [markdown]
# I took count of the scholarship colunms in the various df to help me get the proportion of patients in the question above.

# %%
missed_proportion = missed_scholarship[1] / total_scholarship[1]
missed_proportion
# Out:
# 0.2373630420771568

# %%
meet_proportion = meet_scholarship[1] / total_scholarship[1]
meet_proportion
# Out:
# 0.7626369579228433

# %% [markdown]
# #### 4. Is there any difference in the age distribution of patients that missed their appointments to those who didn't?

# %%
missed_df['age'].hist()
plt.xlabel('Age')
plt.title('Age distribution of patients that missed their appointment');

# %%
meet_df['age'].hist()
plt.xlabel('Age')
plt.title('Age distribution of patients that met their appointment');

# %%
# Let's check if there is any correlation between age and other colunms among patients that missed their appointments
missed_df.corr().style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_56561_row0_col0, #T_56561_row1_col1, #T_56561_row2_col2, #T_56561_row3_col3, #T_56561_row4_col4, #T_56561_row5_col5, #T_56561_row6_col6, #T_56561_row7_col7, #T_56561_row8_col8 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_56561_row0_col1, #T_56561_row0_col8, #T_56561_row1_col3, #T_56561_row4_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_56561_row0_col2, #T_56561_row0_col3, #T_56561_row5_col7, #T_56561_row7_col5 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_56561_row0_col4, #T_56561_row0_col5, #T_56561_row5_col6, #T_56561_row6_col7 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_56561_row0_col6, #T_56561_row1_col0, #T_56561_row1_col8, #T_56561_row2_col3, #T_56561_row3_col2, #T_56561_row3_col4, #T_56561_row5_col0, #T_56561_row6_col0, #T_56561_row7_col0, #T_56561_row8_col0, #T_56561_row8_col1, #T_56561_row8_col4, #T_56561_row8_col5, #T_56561_row8_col6, #T_56561_row8_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_56561_row0_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_56561_row1_col2, #T_56561_row4_col8, #T_56561_row5_col8, #T_56561_row7_col8 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_56561_row1_col4 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_56561_row1_col5 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_56561_row1_col6, #T_56561_row1_col7, #T_56561_row6_col5 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_56561_row2_col0, #T_56561_row3_col0, #T_56561_row3_col5, #T_56561_row3_col7, #T_56561_row4_col0, #T_56561_row7_col6 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_56561_row2_col1, #T_56561_row2_col6, #T_56561_row2_col7, #T_56561_row7_col4 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_56561_row2_col4 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_56561_row2_col5 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_56561_row2_col8, #T_56561_row8_col3 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_56561_row3_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_56561_row3_col6 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_56561_row3_col8, #T_56561_row6_col4, #T_56561_row7_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_56561_row4_col1, #T_56561_row4_col7 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_56561_row4_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_56561_row4_col3, #T_56561_row5_col3, #T_56561_row7_col3 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_56561_row4_col5, #T_56561_row5_col4 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_56561_row5_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_56561_row5_col2 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_56561_row6_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_56561_row6_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_56561_row6_col3 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_56561_row6_col8 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_56561_row7_col2 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_56561_row8_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# </style>
# <table id="T_56561">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56561_level0_col0" class="col_heading level0 col0" >patientid</th>
#       <th id="T_56561_level0_col1" class="col_heading level0 col1" >appointmentid</th>
#       <th id="T_56561_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_56561_level0_col3" class="col_heading level0 col3" >scholarship</th>
#       <th id="T_56561_level0_col4" class="col_heading level0 col4" >hypertensive</th>
#       <th id="T_56561_level0_col5" class="col_heading level0 col5" >diabetic</th>
#       <th id="T_56561_level0_col6" class="col_heading level0 col6" >alcoholic</th>
#       <th id="T_56561_level0_col7" class="col_heading level0 col7" >handicap</th>
#       <th id="T_56561_level0_col8" class="col_heading level0 col8" >sms_received</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56561_level0_row0" class="row_heading level0 row0" >patientid</th>
#       <td id="T_56561_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_56561_row0_col1" class="data row0 col1" >-0.006088</td>
#       <td id="T_56561_row0_col2" class="data row0 col2" >-0.000908</td>
#       <td id="T_56561_row0_col3" class="data row0 col3" >0.000109</td>
#       <td id="T_56561_row0_col4" class="data row0 col4" >0.000230</td>
#       <td id="T_56561_row0_col5" class="data row0 col5" >-0.005386</td>
#       <td id="T_56561_row0_col6" class="data row0 col6" >-0.007139</td>
#       <td id="T_56561_row0_col7" class="data row0 col7" >-0.006776</td>
#       <td id="T_56561_row0_col8" class="data row0 col8" >-0.004195</td>
#     </tr>
#     <tr>
#       <th id="T_56561_level0_row1" class="row_heading level0 row1" >appointmentid</th>
#       <td id="T_56561_row1_col0" class="data row1 col0" >-0.006088</td>
#       <td id="T_56561_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_56561_row1_col2" class="data row1 col2" >0.006243</td>
#       <td id="T_56561_row1_col3" class="data row1 col3" >0.022385</td>
#       <td id="T_56561_row1_col4" class="data row1 col4" >0.011716</td>
#       <td id="T_56561_row1_col5" class="data row1 col5" >0.032301</td>
#       <td id="T_56561_row1_col6" class="data row1 col6" >0.034371</td>
#       <td id="T_56561_row1_col7" class="data row1 col7" >0.015582</td>
#       <td id="T_56561_row1_col8" class="data row1 col8" >-0.114017</td>
#     </tr>
#     <tr>
#       <th id="T_56561_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_56561_row2_col0" class="data row2 col0" >-0.000908</td>
#       <td id="T_56561_row2_col1" class="data row2 col1" >0.006243</td>
#       <td id="T_56561_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_56561_row2_col3" class="data row2 col3" >-0.079770</td>
#       <td id="T_56561_row2_col4" class="data row2 col4" >0.521557</td>
#       <td id="T_56561_row2_col5" class="data row2 col5" >0.306683</td>
#       <td id="T_56561_row2_col6" class="data row2 col6" >0.099859</td>
#       <td id="T_56561_row2_col7" class="data row2 col7" >0.081480</td>
#       <td id="T_56561_row2_col8" class="data row2 col8" >-0.016760</td>
#     </tr>
#     <tr>
#       <th id="T_56561_level0_row3" class="row_heading level0 row3" >scholarship</th>
#       <td id="T_56561_row3_col0" class="data row3 col0" >0.000109</td>
#       <td id="T_56561_row3_col1" class="data row3 col1" >0.022385</td>
#       <td id="T_56561_row3_col2" class="data row3 col2" >-0.079770</td>
#       <td id="T_56561_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_56561_row3_col4" class="data row3 col4" >-0.023824</td>
#       <td id="T_56561_row3_col5" class="data row3 col5" >-0.024142</td>
#       <td id="T_56561_row3_col6" class="data row3 col6" >0.057870</td>
#       <td id="T_56561_row3_col7" class="data row3 col7" >-0.020870</td>
#       <td id="T_56561_row3_col8" class="data row3 col8" >0.015221</td>
#     </tr>
#     <tr>
#       <th id="T_56561_level0_row4" class="row_heading level0 row4" >hypertensive</th>
#       <td id="T_56561_row4_col0" class="data row4 col0" >0.000230</td>
#       <td id="T_56561_row4_col1" class="data row4 col1" >0.011716</td>
#       <td id="T_56561_row4_col2" class="data row4 col2" >0.521557</td>
#       <td id="T_56561_row4_col3" class="data row4 col3" >-0.023824</td>
#       <td id="T_56561_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_56561_row4_col5" class="data row4 col5" >0.439078</td>
#       <td id="T_56561_row4_col6" class="data row4 col6" >0.090336</td>
#       <td id="T_56561_row4_col7" class="data row4 col7" >0.085808</td>
#       <td id="T_56561_row4_col8" class="data row4 col8" >-0.026152</td>
#     </tr>
#     <tr>
#       <th id="T_56561_level0_row5" class="row_heading level0 row5" >diabetic</th>
#       <td id="T_56561_row5_col0" class="data row5 col0" >-0.005386</td>
#       <td id="T_56561_row5_col1" class="data row5 col1" >0.032301</td>
#       <td id="T_56561_

# %% [markdown]
# There is a moderate correlation (0.52) between age and hypertensive patients amongst patients that missed their appointment. is it the same for those that met their appointments?

# %%
meet_df.corr().style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_ea429_row0_col0, #T_ea429_row1_col1, #T_ea429_row2_col2, #T_ea429_row3_col3, #T_ea429_row4_col4, #T_ea429_row5_col5, #T_ea429_row6_col6, #T_ea429_row7_col7, #T_ea429_row8_col8 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ea429_row0_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_ea429_row0_col2, #T_ea429_row5_col7, #T_ea429_row7_col3, #T_ea429_row8_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_ea429_row0_col3, #T_ea429_row7_col5 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_ea429_row0_col4, #T_ea429_row2_col0, #T_ea429_row3_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_ea429_row0_col5, #T_ea429_row6_col0 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_ea429_row0_col6, #T_ea429_row1_col5, #T_ea429_row6_col5 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_ea429_row0_col7, #T_ea429_row5_col0 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_ea429_row0_col8 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_ea429_row1_col0, #T_ea429_row3_col7, #T_ea429_row8_col5 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_ea429_row1_col2, #T_ea429_row5_col6 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_ea429_row1_col3, #T_ea429_row6_col3 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_ea429_row1_col4, #T_ea429_row8_col4 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_ea429_row1_col6 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_ea429_row1_col7 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_ea429_row1_col8, #T_ea429_row2_col3, #T_ea429_row3_col2, #T_ea429_row3_col4, #T_ea429_row3_col5, #T_ea429_row4_col0, #T_ea429_row7_col0, #T_ea429_row8_col0, #T_ea429_row8_col1, #T_ea429_row8_col6, #T_ea429_row8_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ea429_row2_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_ea429_row2_col4 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_ea429_row2_col5 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_ea429_row2_col6 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_ea429_row2_col7, #T_ea429_row4_col7, #T_ea429_row7_col4 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_ea429_row2_col8, #T_ea429_row3_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_ea429_row3_col6 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_ea429_row3_col8, #T_ea429_row5_col8 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_ea429_row4_col1, #T_ea429_row4_col8 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_ea429_row4_col2 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_ea429_row4_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_ea429_row4_col5 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_ea429_row4_col6, #T_ea429_row8_col2 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_ea429_row5_col1 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_ea429_row5_col2 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_ea429_row5_col3 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_ea429_row5_col4 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_ea429_row6_col1 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_ea429_row6_col2 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_ea429_row6_col4 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_ea429_row6_col7 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_ea429_row6_col8 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_ea429_row7_col1 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_ea429_row7_col2 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_ea429_row7_col6 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_ea429_row7_col8 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# </style>
# <table id="T_ea429">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea429_level0_col0" class="col_heading level0 col0" >patientid</th>
#       <th id="T_ea429_level0_col1" class="col_heading level0 col1" >appointmentid</th>
#       <th id="T_ea429_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_ea429_level0_col3" class="col_heading level0 col3" >scholarship</th>
#       <th id="T_ea429_level0_col4" class="col_heading level0 col4" >hypertensive</th>
#       <th id="T_ea429_level0_col5" class="col_heading level0 col5" >diabetic</th>
#       <th id="T_ea429_level0_col6" class="col_heading level0 col6" >alcoholic</th>
#       <th id="T_ea429_level0_col7" class="col_heading level0 col7" >handicap</th>
#       <th id="T_ea429_level0_col8" class="col_heading level0 col8" >sms_received</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea429_level0_row0" class="row_heading level0 row0" >patientid</th>
#       <td id="T_ea429_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ea429_row0_col1" class="data row0 col1" >0.006536</td>
#       <td id="T_ea429_row0_col2" class="data row0 col2" >-0.005023</td>
#       <td id="T_ea429_row0_col3" class="data row0 col3" >-0.003655</td>
#       <td id="T_ea429_row0_col4" class="data row0 col4" >-0.008074</td>
#       <td id="T_ea429_row0_col5" class="data row0 col5" >0.003226</td>
#       <td id="T_ea429_row0_col6" class="data row0 col6" >0.015573</td>
#       <td id="T_ea429_row0_col7" class="data row0 col7" >-0.008204</td>
#       <td id="T_ea429_row0_col8" class="data row0 col8" >-0.011148</td>
#     </tr>
#     <tr>
#       <th id="T_ea429_level0_row1" class="row_heading level0 row1" >appointmentid</th>
#       <td id="T_ea429_row1_col0" class="data row1 col0" >0.006536</td>
#       <td id="T_ea429_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ea429_row1_col2" class="data row1 col2" >-0.038520</td>
#       <td id="T_ea429_row1_col3" class="data row1 col3" >0.029324</td>
#       <td id="T_ea429_row1_col4" class="data row1 col4" >0.005882</td>
#       <td id="T_ea429_row1_col5" class="data row1 col5" >0.017458</td>
#       <td id="T_ea429_row1_col6" class="data row1 col6" >0.033099</td>
#       <td id="T_ea429_row1_col7" class="data row1 col7" >0.012714</td>
#       <td id="T_ea429_row1_col8" class="data row1 col8" >-0.278852</td>
#     </tr>
#     <tr>
#       <th id="T_ea429_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_ea429_row2_col0" class="data row2 col0" >-0.005023</td>
#       <td id="T_ea429_row2_col1" class="data row2 col1" >-0.038520</td>
#       <td id="T_ea429_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ea429_row2_col3" class="data row2 col3" >-0.094027</td>
#       <td id="T_ea429_row2_col4" class="data row2 col4" >0.499720</td>
#       <td id="T_ea429_row2_col5" class="data row2 col5" >0.288777</td>
#       <td id="T_ea429_row2_col6" class="data row2 col6" >0.095083</td>
#       <td id="T_ea429_row2_col7" class="data row2 col7" >0.076972</td>
#       <td id="T_ea429_row2_col8" class="data row2 col8" >0.030199</td>
#     </tr>
#     <tr>
#       <th id="T_ea429_level0_row3" class="row_heading level0 row3" >scholarship</th>
#       <td id="T_ea429_row3_col0" class="data row3 col0" >-0.003655</td>
#       <td id="T_ea429_row3_col1" class="data row3 col1" >0.029324</td>
#       <td id="T_ea429_row3_col2" class="data row3 col2" >-0.094027</td>
#       <td id="T_ea429_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ea429_row3_col4" class="data row3 col4" >-0.017443</td>
#       <td id="T_ea429_row3_col5" class="data row3 col5" >-0.024610</td>
#       <td id="T_ea429_row3_col6" class="data row3 col6" >0.028755</td>
#       <td id="T_ea429_row3_col7" class="data row3 col7" >-0.005103</td>
#       <td id="T_ea429_row3_col8" class="data row3 col8" >-0.007880</td>
#     </tr>
#     <tr>
#       <th id="T_ea429_level0_row4" class="row_heading level0 row4" >hypertensive</th>
#       <td id="T_ea429_row4_col0" class="data row4 col0" >-0.008074</td>
#       <td id="T_ea429_row4_col1" class="data row4 col1" >0.005882</td>
#       <td id="T_ea429_row4_col2" class="data row4 col2" >0.499720</td>
#       <td id="T_ea429_row4_col3" class="data row4 col3" >-0.017443</td>
#       <td id="T_ea42

# %% [markdown]
# There is a weak correlation among these patients.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# From this analysis, I found that
#
# 1. The percentage of patients that did not show up for their appointment is 20.2% with females having a higher fraction of 13.2%.
#
# 2. Jardim Camburi neighbourhood had the highest number of missed appointments.
#
# 3. The proportion of patients with bolsa Familia that missed their appointments was about 0.24.
#
# 4. The age distribution of adult patients who missed their appointments maxed between 20 to 40 years while those that met their appointment maxed between 40 to 60 years and there is a moderate positive correlation between age and hypertensive patients that missed their appointments.

# %% [markdown]
# #### Limitation
#
# since the _neighbourhood_ column indicates the location of the hospital, I think there's need for a column that gives the _patient's address_. That way, we could check if distance from the hospital is a factor that makes patients to miss their appointments.

# %% [markdown]
# Reference
#
# 1. [datagy article on Pandas to_datatime](https://datagy.io/pandas-to-datetime/)
# 2. [w3 schools: Matplotlib pie charts](https://www.w3schools.com/python/matplotlib_pie_charts.asp)
# 3. Pandas Documentation
# 4. Udacity Data Analysis process(casa study 2)
